# %% [markdown]
# # Step 0. xlsx to csv

# %%
import pandas as pd
import os
from pathlib import Path

# %%
def convert_xlsx_to_csv(input_folder, output_folder):
    """
    특정 폴더의 xlsx 파일들을 UTF-8 CSV로 변환
    
    Args:
        input_folder (str): xlsx 파일들이 있는 폴더 경로
        output_folder (str, optional): CSV 파일을 저장할 폴더 경로. None이면 입력 폴더와 동일
    """
    
    # 입력 폴더 경로 설정
    input_path = Path(input_folder)
    
    # 출력 폴더 경로 설정 (지정하지 않으면 입력 폴더와 동일)
    if output_folder is None:
        output_path = input_path
    else:
        output_path = Path(output_folder)
        output_path.mkdir(parents=True, exist_ok=True)  # 폴더가 없으면 생성
    
    # xlsx 파일 찾기
    xlsx_files = list(input_path.glob("*.xlsx"))
    
    # 임시 파일 제외 (Excel 임시 파일은 ~$로 시작)
    xlsx_files = [f for f in xlsx_files if not f.name.startswith('~$')]
    
    if not xlsx_files:
        print(f"'{input_folder}' 폴더에 xlsx 파일이 없습니다.")
        return
    
    print(f"총 {len(xlsx_files)}개의 xlsx 파일을 찾았습니다.")
    
    # 찾은 파일 목록 출력 (디버깅용)
    print("\n찾은 파일 목록:")
    for i, xlsx_file in enumerate(xlsx_files, 1):
        print(f"{i}. {xlsx_file.name}")
    print()
    
    # 각 xlsx 파일을 CSV로 변환
    for xlsx_file in xlsx_files:
        try:
            # 해당 파일의 시트 이름 목록 가져오기
            sheet_name_list = pd.ExcelFile(xlsx_file, engine='openpyxl').sheet_names
            
            # Excel 파일 읽기 (한글 깨짐 방지)
            df = pd.read_excel(xlsx_file, sheet_name=sheet_name_list[2], engine='openpyxl')
            
            # CSV 파일명 생성 (확장자만 변경)
            csv_filename = xlsx_file.stem + ".csv"
            csv_path = output_path / csv_filename
            
            # UTF-8 BOM 포함하여 CSV 저장 (Excel에서도 한글 정상 표시)
            df.to_csv(csv_path, index=False, encoding='utf-8-sig')
            
            print(f"✓ {xlsx_file.name} → {csv_filename} 변환 완료")
            
        except Exception as e:
            print(f"✗ {xlsx_file.name} 변환 실패: {e}")

# %%
# 폴더 경로 설정 (현재 작업 디렉토리 기준)
# xlsx폴더 내부에 존재하는 2015~2025폴더를 순차적으로 접근하여 작업 진행
base_input_folder = "./xlsx"
base_output_folder = "./csv"
for year in range(2015, 2026):
    input_folder = os.path.join(base_input_folder, str(year))
    if os.path.exists(input_folder):
        convert_xlsx_to_csv(input_folder, base_output_folder)
    else:
        print(f"폴더가 존재하지 않습니다: {input_folder}")
# Out:
# 총 8개의 xlsx 파일을 찾았습니다.
#
# 찾은 파일 목록:
# 1. (2015) 7월말+주민등록인구+및+외국인+현황 (1).xlsx
# 2. (2015) 9월말+주민등록인구+및+외국인+현황 (1).xlsx
# 3. (2015) 12월말+주민등록인구+및+외국인+현황 (1).xlsx
# 4. (2015) 5월말+주민등록인구+및+외국인+현황 (1).xlsx
# 5. (2015) 6월말+주민등록인구+및+외국인+현황 (1).xlsx
# 6. (2015) 11월말+주민등록인구+및+외국인+현황 (1).xlsx
# 7. (2015) 8월말+주민등록인구+및+외국인+현황 (1).xlsx
# 8. (2015) 10월말+주민등록인구+및+외국인+현황 (1).xlsx
#
# ✓ (2015) 7월말+주민등록인구+및+외국인+현황 (1).xlsx → (2015) 7월말+주민등록인구+및+외국인+현황 (1).csv 변환 완료
# ✓ (2015) 9월말+주민등록인구+및+외국인+현황 (1).xlsx → (2015) 9월말+주민등록인구+및+외국인+현황 (1).csv 변환 완료
# ✓ (2015) 12월말+주민등록인구+및+외국인+현황 (1).xlsx → (2015) 12월말+주민등록인구+및+외국인+현황 (1).csv 변환 완료
# ✓ (2015) 5월말+주민등록인구+및+외국인+현황 (1).xlsx → (2015) 5월말+주민등록인구+및+외국인+현황 (1).csv 변환 완료
# ✓ (2015) 6월말+주민등록인구+및+외국인+현황 (1).xlsx → (2015) 6월말+주민등록인구+및+외국인+현황 (1).csv 변환 완료
# ✓ (2015) 11월말+주민등록인구+및+외국인+현황 (1).xlsx → (2015) 11월말+주민등록인구+및+외국인+현황 (1).csv 변환 완료
# ✓ (2015) 8월말+주민등록인구+및+외국인+현황 (1).xlsx → (2015) 8월말+주민등록인구+및+외국인+현황 (1).csv 변환 완료
# ✓ (2015) 10월말+주민등록인구+및+외국인+현황 (1).xlsx → (2015) 10월말+주민등록인구+및+외국인+현황 (1).csv 변환 완료
# 총 12개의 xlsx 파일을 찾았습니다.
#
# 찾은 파일 목록:
# 1. (2016) 11월말+주민등록인구+및+외국인+현황.xlsx
# 2. (2016) 4월말+주민등록인구+및+외국인+현황.xlsx
# 3. (2016) 12월말+주민등록인구+및+외국인+현황.xlsx
# 4. (2016) 1월말+주민등록인구+및+외국인+현황.xlsx
# 5. (2016) 9월말+주민등록인구+및+외국인+현황.xlsx
# 6. (2016) 2월말+주민등록인구+및+외국인+현황.xlsx
# 7. (2016) 8월말+주민등록인구+및+외국인+현황.xlsx
# 8. (2016) 6월말+주민등록인구+및+외국인+현황.xlsx
# 9. (2016) 3월말+주민등록인구+및+외국인+현황.xlsx
# 10. (2016) 7월말+주민등록인구+및+외국인+현황.xlsx
# 11. (2016) 5월말+주민등록인구+및+외국인+현황.xlsx
# 12. (2016) 10월말+주민등록인구+및+외국인+현황.xlsx
#
# ✓ (2016) 11월말+주민등록인구+및+외국인+현황.xlsx → (2016) 11월말+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ (2016) 4월말+주민등록인구+및+외국인+현황.xlsx → (2016) 4월말+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ (2016) 12월말+주민등록인구+및+외국인+현황.xlsx → (2016) 12월말+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ (2016) 1월말+주민등록인구+및+외국인+현황.xlsx → (2016) 1월말+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ (2016) 9월말+주민등록인구+및+외국인+현황.xlsx → (2016) 9월말+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ (2016) 2월말+주민등록인구+및+외국인+현황.xlsx → (2016) 2월말+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ (2016) 8월말+주민등록인구+및+외국인+현황.xlsx → (2016) 8월말+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ (2016) 6월말+주민등록인구+및+외국인+현황.xlsx → (2016) 6월말+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ (2016) 3월말+주민등록인구+및+외국인+현황.xlsx → (2016) 3월말+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ (2016) 7월말+주민등록인구+및+외국인+현황.xlsx → (2016) 7월말+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ (2016) 5월말+주민등록인구+및+외국인+현황.xlsx → (2016) 5월말+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ (2016) 10월말+주민등록인구+및+외국인+현황.xlsx → (2016) 10월말+주민등록인구+및+외국인+현황.csv 변환 완료
# 총 12개의 xlsx 파일을 찾았습니다.
#
# 찾은 파일 목록:
# 1. 2017년+6월말_주민등록인구_및_외국인_현황.xlsx
# 2. 2017년+2월말_주민등록인구_및_외국인_현황.xlsx
# 3. 2017년+4월말_주민등록인구_및_외국인_현황.xlsx
# 4. 2017년+8월말_주민등록인구_및_외국인_현황.xlsx
# 5. 2017년+1월말_주민등록인구_및_외국인_현황.xlsx
# 6. 2017년+12월말_주민등록인구_및_외국인_현황.xlsx
# 7. 2017년+5월말_주민등록인구_및_외국인_현황.xlsx
# 8. 2017년+3월말_주민등록인구_및_외국인_현황.xlsx
# 9. 2017년+10월말_주민등록인구_및_외국인_현황.xlsx
# 10. 2017년+9월말_주민등록인구_및_외국인_현황.xlsx
# 11. 2017년+7월말_주민등록인구_및_외국인_현황.xlsx
# 12. 2017년+11월말_주민등록인구_및_외국인_현황.xlsx
#
# ✓ 2017년+6월말_주민등록인구_및_외국인_현황.xlsx → 2017년+6월말_주민등록인구_및_외국인_현황.csv 변환 완료
# ✓ 2017년+2월말_주민등록인구_및_외국인_현황.xlsx → 2017년+2월말_주민등록인구_및_외국인_현황.csv 변환 완료
# ✓ 2017년+4월말_주민등록인구_및_외국인_현황.xlsx → 2017년+4월말_주민등록인구_및_외국인_현황.csv 변환 완료
# ✓ 2017년+8월말_주민등록인구_및_외국인_현황.xlsx → 2017년+8월말_주민등록인구_및_외국인_현황.csv 변환 완료
# ✓ 2017년+1월말_주민등록인구_및_외국인_현황.xlsx → 2017년+1월말_주민등록인구_및_외국인_현황.csv 변환 완료
# ✓ 2017년+12월말_주민등록인구_및_외국인_현황.xlsx → 2017년+12월말_주민등록인구_및_외국인_현황.csv 변환 완료
# ✓ 2017년+5월말_주민등록인구_및_외국인_현황.xlsx → 2017년+5월말_주민등록인구_및_외국인_현황.csv 변환 완료
# ✓ 2017년+3월말_주민등록인구_및_외국인_현황.xlsx → 2017년+3월말_주민등록인구_및_외국인_현황.csv 변환 완료
# ✓ 2017년+10월말_주민등록인구_및_외국인_현황.xlsx → 2017년+10월말_주민등록인구_및_외국인_현황.csv 변환 완료
# ✓ 2017년+9월말_주민등록인구_및_외국인_현황.xlsx → 2017년+9월말_주민등록인구_및_외국인_현황.csv 변환 완료
# ✓ 2017년+7월말_주민등록인구_및_외국인_현황.xlsx → 2017년+7월말_주민등록인구_및_외국인_현황.csv 변환 완료
# ✓ 2017년+11월말_주민등록인구_및_외국인_현황.xlsx → 2017년+11월말_주민등록인구_및_외국인_현황.csv 변환 완료
# 총 12개의 xlsx 파일을 찾았습니다.
#
# 찾은 파일 목록:
# 1. 2018년+11월말+주민등록인구+및+외국인+현황.xlsx
# 2. 2018년+2월말+주민등록인구+및+외국인+현황.xlsx
# 3. 2018년+5월말+주민등록인구+및+외국인+현황.xlsx
# 4. 2018년+9월말+주민등록인구+및+외국인+현황.xlsx
# 5. 2018년+6월말+주민등록인구+및+외국인+현황.xlsx
# 6. 2018년+10월말+주민등록인구+및+외국인+현황.xlsx
# 7. 2018년+12월말+주민등록인구+및+외국인+현황.xlsx
# 8. 2018년+7월말+주민등록인구+및+외국인+현황.xlsx
# 9. 2018년+8월말+주민등록인구+및+외국인+현황.xlsx
# 10. 2018년+1월말+주민등록인구+및+외국인+현황.xlsx
# 11. 2018년+3월말+주민등록인구+및+외국인+현황.xlsx
# 12. 2018년+4월말+주민등록인구+및+외국인+현황.xlsx
#
# ✓ 2018년+11월말+주민등록인구+및+외국인+현황.xlsx → 2018년+11월말+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2018년+2월말+주민등록인구+및+외국인+현황.xlsx → 2018년+2월말+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2018년+5월말+주민등록인구+및+외국인+현황.xlsx → 2018년+5월말+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2018년+9월말+주민등록인구+및+외국인+현황.xlsx → 2018년+9월말+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2018년+6월말+주민등록인구+및+외국인+현황.xlsx → 2018년+6월말+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2018년+10월말+주민등록인구+및+외국인+현황.xlsx → 2018년+10월말+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2018년+12월말+주민등록인구+및+외국인+현황.xlsx → 2018년+12월말+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2018년+7월말+주민등록인구+및+외국인+현황.xlsx → 2018년+7월말+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2018년+8월말+주민등록인구+및+외국인+현황.xlsx → 2018년+8월말+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2018년+1월말+주민등록인구+및+외국인+현황.xlsx → 2018년+1월말+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2018년+3월말+주민등록인구+및+외국인+현황.xlsx → 2018년+3월말+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2018년+4월말+주민등록인구+및+외국인+현황.xlsx → 2018년+4월말+주민등록인구+및+외국인+현황.csv 변환 완료
# 총 12개의 xlsx 파일을 찾았습니다.
#
# 찾은 파일 목록:
# 1. 2019년+11월말+창원시+주민등록인구+및+외국인+현황.xlsx
# 2. 2019년+9월말+창원시+주민등록인구+및+외국인+현황.xlsx
# 3. 2019년+1월말+창원시+주민등록인구+및+외국인+현황.xlsx
# 4. 2019년+4월말+창원시+주민등록인구+및+외국인+현황.xlsx
# 5. 2019년+2월말+창원시+주민등록인구+및+외국인+현황.xlsx
# 6. 2019년+3월말+창원시+주민등록인구+및+외국인+현황.xlsx
# 7. 2019년+12월말+창원시+주민등록인구+및+외국인+현황.xlsx
# 8. 2019년+5월말+창원시+주민등록인구+및+외국인+현황.xlsx
# 9. 2019년+6월말+창원시+주민등록인구+및+외국인+현황.xlsx
# 10. 2019년+7월말+창원시+주민등록인구+및+외국인+현황.xlsx
# 11. 2019년+8월말+창원시+주민등록인구(외국인+제외).xlsx
# 12. 2019년+10월말+창원시+주민등록인구+및+외국인+현황.xlsx
#
# ✓ 2019년+11월말+창원시+주민등록인구+및+외국인+현황.xlsx → 2019년+11월말+창원시+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2019년+9월말+창원시+주민등록인구+및+외국인+현황.xlsx → 2019년+9월말+창원시+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2019년+1월말+창원시+주민등록인구+및+외국인+현황.xlsx → 2019년+1월말+창원시+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2019년+4월말+창원시+주민등록인구+및+외국인+현황.xlsx → 2019년+4월말+창원시+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2019년+2월말+창원시+주민등록인구+및+외국인+현황.xlsx → 2019년+2월말+창원시+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2019년+3월말+창원시+주민등록인구+및+외국인+현황.xlsx → 2019년+3월말+창원시+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2019년+12월말+창원시+주민등록인구+및+외국인+현황.xlsx → 2019년+12월말+창원시+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2019년+5월말+창원시+주민등록인구+및+외국인+현황.xlsx → 2019년+5월말+창원시+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2019년+6월말+창원시+주민등록인구+및+외국인+현황.xlsx → 2019년+6월말+창원시+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2019년+7월말+창원시+주민등록인구+및+외국인+현황.xlsx → 2019년+7월말+창원시+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2019년+8월말+창원시+주민등록인구(외국인+제외).xlsx → 2019년+8월말+창원시+주민등록인구(외국인+제외).csv 변환 완료
# ✓ 2019년+10월말+창원시+주민등록인구+및+외국인+현황.xlsx → 2019년+10월말+창원시+주민등록인구+및+외국인+현황.csv 변환 완료
# 총 12개의 xlsx 파일을 찾았습니다.
#
# 찾은 파일 목록:
# 1. 2020년+3월말+창원시+주민등록인구+및+외국인+현황.xlsx
# 2. 2020년+1월말+창원시+주민등록인구+및+외국인+현황.xlsx
# 3. 2020년+7월말+창원시+주민등록인구+및+외국인+현황.xlsx
# 4. 2020년+11월말 창원시 주민등록인구 및 외국인 현황.xlsx
# 5. 2020년+2월말+창원시+주민등록인구+및+외국인+현황.xlsx
# 6. 2020년+4월말+창원시+주민등록인구+및+외국인+현황.xlsx
# 7. 2020년+12월말 창원시 주민등록인구 및 외국인 현황.xlsx
# 8. 2020년+10월말 창원시 주민등록인구 및 외국인 현황.xlsx
# 9. 2020년+8월말+창원시+주민등록인구+및+외국인+현황.xlsx
# 10. 2020년+9월말+창원시+주민등록인구+및+외국인+현황.xlsx
# 11. 2020년+5월말+창원시+주민등록인구+및+외국인+현황.xlsx
# 12. 2020년+6월말+창원시+주민등록인구+및+외국인+현황.xlsx
#
# ✓ 2020년+3월말+창원시+주민등록인구+및+외국인+현황.xlsx → 2020년+3월말+창원시+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2020년+1월말+창원시+주민등록인구+및+외국인+현황.xlsx → 2020년+1월말+창원시+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2020년+7월말+창원시+주민등록인구+및+외국인+현황.xlsx → 2020년+7월말+창원시+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2020년+11월말 창원시 주민등록인구 및 외국인 현황.xlsx → 2020년+11월말 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ 2020년+2월말+창원시+주민등록인구+및+외국인+현황.xlsx → 2020년+2월말+창원시+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2020년+4월말+창원시+주민등록인구+및+외국인+현황.xlsx → 2020년+4월말+창원시+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2020년+12월말 창원시 주민등록인구 및 외국인 현황.xlsx → 2020년+12월말 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ 2020년+10월말 창원시 주민등록인구 및 외국인 현황.xlsx → 2020년+10월말 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ 2020년+8월말+창원시+주민등록인구+및+외국인+현황.xlsx → 2020년+8월말+창원시+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2020년+9월말+창원시+주민등록인구+및+외국인+현황.xlsx → 2020년+9월말+창원시+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2020년+5월말+창원시+주민등록인구+및+외국인+현황.xlsx → 2020년+5월말+창원시+주민등록인구+및+외국인+현황.csv 변환 완료
# ✓ 2020년+6월말+창원시+주민등록인구+및+외국인+현황.xlsx → 2020년+6월말+창원시+주민등록인구+및+외국인+현황.csv 변환 완료
# 총 12개의 xlsx 파일을 찾았습니다.
#
# 찾은 파일 목록:
# 1. (21.7월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 2. (21.1월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 3. (21.12월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 4. (21.3월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 5. (21.4월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 6. (21.5월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 7. (21.2월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 8. (21.10월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 9. (21.6월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 10. (21.11월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 11. (21.9월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 12. (21.8월말) 창원시 주민등록인구 및 외국인 현황.xlsx
#
# ✓ (21.7월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (21.7월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (21.1월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (21.1월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (21.12월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (21.12월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (21.3월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (21.3월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (21.4월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (21.4월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (21.5월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (21.5월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (21.2월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (21.2월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (21.10월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (21.10월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (21.6월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (21.6월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (21.11월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (21.11월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (21.9월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (21.9월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (21.8월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (21.8월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# 총 12개의 xlsx 파일을 찾았습니다.
#
# 찾은 파일 목록:
# 1. (2022. 4월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 2. (2022. 10월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 3. (2022. 8월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 4. (2022. 6월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 5. (2022. 5월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 6. (2022. 7월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 7. (2022. 2월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 8. (2022. 12월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 9. (2022. 3월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 10. (2022. 9월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 11. (2022. 1월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 12. (2022. 11월말) 창원시 주민등록인구 및 외국인 현황.xlsx
#
# ✓ (2022. 4월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2022. 4월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2022. 10월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2022. 10월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2022. 8월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2022. 8월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2022. 6월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2022. 6월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2022. 5월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2022. 5월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2022. 7월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2022. 7월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2022. 2월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2022. 2월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2022. 12월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2022. 12월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2022. 3월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2022. 3월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2022. 9월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2022. 9월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2022. 1월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2022. 1월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2022. 11월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2022. 11월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# 총 12개의 xlsx 파일을 찾았습니다.
#
# 찾은 파일 목록:
# 1. (2023. 3월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 2. (2023. 5월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 3. (2023. 11월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 4. (2023. 10월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 5. (2023. 6월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 6. (2023. 2월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 7. (2023. 12월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 8. (2023. 4월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 9. (2023. 1월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 10. (2023. 9월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 11. (2023. 7월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 12. (2023. 8월말) 창원시 주민등록인구 및 외국인 현황.xlsx
#
# ✓ (2023. 3월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2023. 3월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2023. 5월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2023. 5월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2023. 11월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2023. 11월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2023. 10월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2023. 10월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2023. 6월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2023. 6월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2023. 2월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2023. 2월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2023. 12월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2023. 12월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2023. 4월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2023. 4월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2023. 1월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2023. 1월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2023. 9월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2023. 9월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2023. 7월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2023. 7월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2023. 8월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2023. 8월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# 총 12개의 xlsx 파일을 찾았습니다.
#
# 찾은 파일 목록:
# 1. (2024. 12월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 2. (2024. 10월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 3. (2024. 3월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 4. (2024. 5월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 5. (2024. 1월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 6. (2024. 9월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 7. (2024. 2월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 8. (2024. 7월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 9. (2024. 4월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 10. (2024. 6월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 11. (2024. 11월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 12. (2024. 8월말) 창원시 주민등록인구 및 외국인 현황.xlsx
#
# ✓ (2024. 12월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2024. 12월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2024. 10월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2024. 10월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2024. 3월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2024. 3월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2024. 5월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2024. 5월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2024. 1월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2024. 1월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2024. 9월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2024. 9월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2024. 2월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2024. 2월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2024. 7월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2024. 7월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2024. 4월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2024. 4월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2024. 6월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2024. 6월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2024. 11월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2024. 11월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2024. 8월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2024. 8월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# 총 8개의 xlsx 파일을 찾았습니다.
#
# 찾은 파일 목록:
# 1. (2025. 2월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 2. (2025. 8월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 3. (2025. 3월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 4. (2025. 7월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 5. (2025. 5월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 6. (2025. 6월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 7. (2025. 4월말) 창원시 주민등록인구 및 외국인 현황.xlsx
# 8. (2025. 1월말) 창원시 주민등록인구 및 외국인 현황.xlsx
#
# ✓ (2025. 2월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2025. 2월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2025. 8월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2025. 8월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2025. 3월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2025. 3월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2025. 7월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2025. 7월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2025. 5월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2025. 5월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2025. 6월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2025. 6월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2025. 4월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2025. 4월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
# ✓ (2025. 1월말) 창원시 주민등록인구 및 외국인 현황.xlsx → (2025. 1월말) 창원시 주민등록인구 및 외국인 현황.csv 변환 완료
