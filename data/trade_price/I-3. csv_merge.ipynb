# %% [markdown]
# # '행정동 - 주택유형'으로 매핑된 데이터프레임 임베딩 작업

# %%
import os
import pandas as pd
from pathlib import Path

csv_files = []
input_folder = './csv_preprocessing'

for dirpath, dirnames, filenames in os.walk(input_folder):
    for filename in filenames:
        if filename.endswith(".csv"):
            csv_files.append(Path(dirpath) / filename)
csv_files

# csv_files 있는 모든 xlsx 파일을 읽어서 각각 csv로 저장
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl")

for csv_file in csv_files:
    # csv_file의 이름 추출하여 df 이름으로 사용
    df_name = csv_file.stem.replace(" ", "_").replace("-", "_").replace(".", "_")
    # csv 파일 읽어서 df_name의 이름을 가진 DataFrame으로 저장.
    globals()[df_name] = pd.read_csv(csv_file)
    print(f"Loaded {csv_file} into DataFrame '{df_name}' with shape {globals()[df_name].shape}")
# Out:
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/4. 마산회원구_오피스텔(매매)_실거래가_1607-1706.csv into DataFrame '4__마산회원구_오피스텔(매매)_실거래가_1607_1706' with shape (110, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/5. 진해구_오피스텔(매매)_실거래가_1607-1706.csv into DataFrame '5__진해구_오피스텔(매매)_실거래가_1607_1706' with shape (150, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/1. 의창구_오피스텔(매매)_실거래가_1501-1506.csv into DataFrame '1__의창구_오피스텔(매매)_실거래가_1501_1506' with shape (72, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/1. 의창구_오피스텔(매매)_실거래가_1507-1606.csv into DataFrame '1__의창구_오피스텔(매매)_실거래가_1507_1606' with shape (117, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/3. 마산합포구_오피스텔(매매)_실거래가_1807-1906.csv into DataFrame '3__마산합포구_오피스텔(매매)_실거래가_1807_1906' with shape (154, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/2. 성산구_오피스텔(매매)_실거래가_1607-1706.csv into DataFrame '2__성산구_오피스텔(매매)_실거래가_1607_1706' with shape (236, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/3. 마산합포구_오피스텔(매매)_실거래가_1507-1606.csv into DataFrame '3__마산합포구_오피스텔(매매)_실거래가_1507_1606' with shape (343, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/3. 마산합포구_오피스텔(매매)_실거래가_1707-1806.csv into DataFrame '3__마산합포구_오피스텔(매매)_실거래가_1707_1806' with shape (133, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/3. 마산합포구_오피스텔(매매)_실거래가_1607-1706.csv into DataFrame '3__마산합포구_오피스텔(매매)_실거래가_1607_1706' with shape (219, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/2. 성산구_오피스텔(매매)_실거래가_1507-1606.csv into DataFrame '2__성산구_오피스텔(매매)_실거래가_1507_1606' with shape (259, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/4. 마산회원구_오피스텔(매매)_실거래가_1501-1506.csv into DataFrame '4__마산회원구_오피스텔(매매)_실거래가_1501_1506' with shape (17, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/4. 마산회원구_오피스텔(매매)_실거래가_1707-1806.csv into DataFrame '4__마산회원구_오피스텔(매매)_실거래가_1707_1806' with shape (63, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/5. 진해구_오피스텔(매매)_실거래가_1501-1506.csv into DataFrame '5__진해구_오피스텔(매매)_실거래가_1501_1506' with shape (16, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/2. 성산구_오피스텔(매매)_실거래가_1707-1806.csv into DataFrame '2__성산구_오피스텔(매매)_실거래가_1707_1806' with shape (118, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/1. 의창구_오피스텔(매매)_실거래가_1707-1806.csv into DataFrame '1__의창구_오피스텔(매매)_실거래가_1707_1806' with shape (71, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/3. 마산합포구_오피스텔(매매)_실거래가_1501-1506.csv into DataFrame '3__마산합포구_오피스텔(매매)_실거래가_1501_1506' with shape (125, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/4. 마산회원구_오피스텔(매매)_실거래가_1807-1906.csv into DataFrame '4__마산회원구_오피스텔(매매)_실거래가_1807_1906' with shape (57, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/4. 마산회원구_오피스텔(매매)_실거래가_1907-2006.csv into DataFrame '4__마산회원구_오피스텔(매매)_실거래가_1907_2006' with shape (36, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/2. 성산구_오피스텔(매매)_실거래가_1907-2006.csv into DataFrame '2__성산구_오피스텔(매매)_실거래가_1907_2006' with shape (195, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/5. 진해구_오피스텔(매매)_실거래가_1707-1806.csv into DataFrame '5__진해구_오피스텔(매매)_실거래가_1707_1806' with shape (18, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/4. 마산회원구_오피스텔(매매)_실거래가_1507-1606.csv into DataFrame '4__마산회원구_오피스텔(매매)_실거래가_1507_1606' with shape (93, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/1. 의창구_오피스텔(매매)_실거래가_1607-1706.csv into DataFrame '1__의창구_오피스텔(매매)_실거래가_1607_1706' with shape (88, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/2. 성산구_오피스텔(매매)_실거래가_1501-1506.csv into DataFrame '2__성산구_오피스텔(매매)_실거래가_1501_1506' with shape (196, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/5. 진해구_오피스텔(매매)_실거래가_1807-1906.csv into DataFrame '5__진해구_오피스텔(매매)_실거래가_1807_1906' with shape (13, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/2. 성산구_오피스텔(매매)_실거래가_1807-1906.csv into DataFrame '2__성산구_오피스텔(매매)_실거래가_1807_1906' with shape (162, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/3. 마산합포구_오피스텔(매매)_실거래가_1907-2006.csv into DataFrame '3__마산합포구_오피스텔(매매)_실거래가_1907_2006' with shape (161, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/1. 의창구_오피스텔(매매)_실거래가_1907-2006.csv into DataFrame '1__의창구_오피스텔(매매)_실거래가_1907_2006' with shape (94, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/5. 진해구_오피스텔(매매)_실거래가_1907-2006.csv into DataFrame '5__진해구_오피스텔(매매)_실거래가_1907_2006' with shape (27, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/1. 의창구_오피스텔(매매)_실거래가_1807-1906.csv into DataFrame '1__의창구_오피스텔(매매)_실거래가_1807_1906' with shape (46, 12)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 201501~202006/5. 진해구_오피스텔(매매)_실거래가_1507-1606.csv into DataFrame '5__진해구_오피스텔(매매)_실거래가_1507_1606' with shape (43, 12)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_2021년_마산회원구.csv into DataFrame '단독다가구(매매)_실거래가_2021년_마산회원구' with shape (395, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_2024년_진해구.csv into DataFrame '단독다가구(매매)_실거래가_2024년_진해구' with shape (180, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_2021년_마산합포구.csv into DataFrame '단독다가구(매매)_실거래가_2021년_마산합포구' with shape (1000, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_2023년_마산합포구.csv into DataFrame '단독다가구(매매)_실거래가_2023년_마산합포구' with shape (260, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_202007_마산합포구.csv into DataFrame '단독다가구(매매)_실거래가_202007_마산합포구' with shape (319, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_2024년_마산합포구.csv into DataFrame '단독다가구(매매)_실거래가_2024년_마산합포구' with shape (233, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_2023년_진해구.csv into DataFrame '단독다가구(매매)_실거래가_2023년_진해구' with shape (194, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_2022년_마산합포구.csv into DataFrame '단독다가구(매매)_실거래가_2022년_마산합포구' with shape (427, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_2024년_성산구.csv into DataFrame '단독다가구(매매)_실거래가_2024년_성산구' with shape (66, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_202007_성산구.csv into DataFrame '단독다가구(매매)_실거래가_202007_성산구' with shape (186, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_2023년_의창구.csv into DataFrame '단독다가구(매매)_실거래가_2023년_의창구' with shape (179, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_2024년_의창구.csv into DataFrame '단독다가구(매매)_실거래가_2024년_의창구' with shape (187, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_202007_의창구.csv into DataFrame '단독다가구(매매)_실거래가_202007_의창구' with shape (254, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_2022년_진해구.csv into DataFrame '단독다가구(매매)_실거래가_2022년_진해구' with shape (287, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_2022년_마산회원구.csv into DataFrame '단독다가구(매매)_실거래가_2022년_마산회원구' with shape (230, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_2022년_의창구.csv into DataFrame '단독다가구(매매)_실거래가_2022년_의창구' with shape (246, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_2021년_의창구.csv into DataFrame '단독다가구(매매)_실거래가_2021년_의창구' with shape (400, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_2022007_마산회원구.csv into DataFrame '단독다가구(매매)_실거래가_2022007_마산회원구' with shape (207, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_2021년_성산구.csv into DataFrame '단독다가구(매매)_실거래가_2021년_성산구' with shape (203, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_2023년_마산회원구.csv into DataFrame '단독다가구(매매)_실거래가_2023년_마산회원구' with shape (160, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_2023년_성산구.csv into DataFrame '단독다가구(매매)_실거래가_2023년_성산구' with shape (81, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_2022년_성산구.csv into DataFrame '단독다가구(매매)_실거래가_2022년_성산구' with shape (117, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_2024년_마산회원구.csv into DataFrame '단독다가구(매매)_실거래가_2024년_마산회원구' with shape (169, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_2021년_진해구.csv into DataFrame '단독다가구(매매)_실거래가_2021년_진해구' with shape (432, 17)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 202007~2024년/단독다가구(매매)_실거래가_202007_진해구.csv into DataFrame '단독다가구(매매)_실거래가_202007_진해구' with shape (194, 17)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/2. 성산구_아파트(매매)_실거래가_1501-1506.csv into DataFrame '2__성산구_아파트(매매)_실거래가_1501_1506' with shape (2921, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/1. 의창구_아파트(매매)_실거래가_1807-1906.csv into DataFrame '1__의창구_아파트(매매)_실거래가_1807_1906' with shape (1226, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/4. 마산회원구_아파트(매매)_실거래가_1907-2006.csv into DataFrame '4__마산회원구_아파트(매매)_실거래가_1907_2006' with shape (2451, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/4. 마산회원구_아파트(매매)_실거래가_1507-1606.csv into DataFrame '4__마산회원구_아파트(매매)_실거래가_1507_1606' with shape (2158, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/2. 성산구_아파트(매매)_실거래가_1607-1706.csv into DataFrame '2__성산구_아파트(매매)_실거래가_1607_1706' with shape (2603, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/4. 마산회원구_아파트(매매)_실거래가_1807-1906.csv into DataFrame '4__마산회원구_아파트(매매)_실거래가_1807_1906' with shape (1323, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/1. 의창구_아파트(매매)_실거래가_1707-1806.csv into DataFrame '1__의창구_아파트(매매)_실거래가_1707_1806' with shape (1029, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/5. 진해구_아파트(매매)_실거래가_1607-1706.csv into DataFrame '5__진해구_아파트(매매)_실거래가_1607_1706' with shape (2150, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/4. 마산회원구_아파트(매매)_실거래가_1501-1506.csv into DataFrame '4__마산회원구_아파트(매매)_실거래가_1501_1506' with shape (1355, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/3. 마산합포구_아파트(매매)_실거래가_1907-2006.csv into DataFrame '3__마산합포구_아파트(매매)_실거래가_1907_2006' with shape (1785, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/3. 마산합포구_아파트(매매)_실거래가_1707-1806.csv into DataFrame '3__마산합포구_아파트(매매)_실거래가_1707_1806' with shape (1099, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/1. 의창구_아파트(매매)_실거래가_1501-1506.csv into DataFrame '1__의창구_아파트(매매)_실거래가_1501_1506' with shape (1454, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/1. 의창구_아파트(매매)_실거래가_1607-1706.csv into DataFrame '1__의창구_아파트(매매)_실거래가_1607_1706' with shape (1435, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/1. 의창구_아파트(매매)_실거래가_1507-1606.csv into DataFrame '1__의창구_아파트(매매)_실거래가_1507_1606' with shape (1561, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/5. 진해구_아파트(매매)_실거래가_1907-2006.csv into DataFrame '5__진해구_아파트(매매)_실거래가_1907_2006' with shape (2273, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/4. 마산회원구_아파트(매매)_실거래가_1607-1706.csv into DataFrame '4__마산회원구_아파트(매매)_실거래가_1607_1706' with shape (1606, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/2. 성산구_아파트(매매)_실거래가_1507-1606.csv into DataFrame '2__성산구_아파트(매매)_실거래가_1507_1606' with shape (3277, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/2. 성산구_아파트(매매)_실거래가_1707-1806.csv into DataFrame '2__성산구_아파트(매매)_실거래가_1707_1806' with shape (2708, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/3. 마산합포구_아파트(매매)_실거래가_1807-1906.csv into DataFrame '3__마산합포구_아파트(매매)_실거래가_1807_1906' with shape (986, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/1. 의창구_아파트(매매)_실거래가_1907-2006.csv into DataFrame '1__의창구_아파트(매매)_실거래가_1907_2006' with shape (2872, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/5. 진해구_아파트(매매)_실거래가_1807-1906.csv into DataFrame '5__진해구_아파트(매매)_실거래가_1807_1906' with shape (1330, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/4. 마산회원구_아파트(매매)_실거래가_1707-1806.csv into DataFrame '4__마산회원구_아파트(매매)_실거래가_1707_1806' with shape (1059, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/5. 진해구_아파트(매매)_실거래가_1707-1806.csv into DataFrame '5__진해구_아파트(매매)_실거래가_1707_1806' with shape (1338, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/5. 진해구_아파트(매매)_실거래가_1507-1606.csv into DataFrame '5__진해구_아파트(매매)_실거래가_1507_1606' with shape (1869, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/2. 성산구_아파트(매매)_실거래가_1807-1906.csv into DataFrame '2__성산구_아파트(매매)_실거래가_1807_1906' with shape (3078, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/3. 마산합포구_아파트(매매)_실거래가_1507-1606.csv into DataFrame '3__마산합포구_아파트(매매)_실거래가_1507_1606' with shape (1457, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/2. 성산구_아파트(매매)_실거래가_1907-2006.csv into DataFrame '2__성산구_아파트(매매)_실거래가_1907_2006' with shape (5413, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/5. 진해구_아파트(매매)_실거래가_1501-1506.csv into DataFrame '5__진해구_아파트(매매)_실거래가_1501_1506' with shape (1348, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/3. 마산합포구_아파트(매매)_실거래가_1501-1506.csv into DataFrame '3__마산합포구_아파트(매매)_실거래가_1501_1506' with shape (1185, 12)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 201501~202006/3. 마산합포구_아파트(매매)_실거래가_1607-1706.csv into DataFrame '3__마산합포구_아파트(매매)_실거래가_1607_1706' with shape (1397, 12)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_2024년_마산합포구.csv into DataFrame '연립다세대(매매)_실거래가_2024년_마산합포구' with shape (45, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_2024년_마산회원구.csv into DataFrame '연립다세대(매매)_실거래가_2024년_마산회원구' with shape (130, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_202007_마산합포구.csv into DataFrame '연립다세대(매매)_실거래가_202007_마산합포구' with shape (32, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_2023년_진해구.csv into DataFrame '연립다세대(매매)_실거래가_2023년_진해구' with shape (192, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_2022년_성산구.csv into DataFrame '연립다세대(매매)_실거래가_2022년_성산구' with shape (16, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_2023년_마산회원구.csv into DataFrame '연립다세대(매매)_실거래가_2023년_마산회원구' with shape (162, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_2022년_진해구.csv into DataFrame '연립다세대(매매)_실거래가_2022년_진해구' with shape (209, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_2024년_성산구.csv into DataFrame '연립다세대(매매)_실거래가_2024년_성산구' with shape (26, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_2022년_마산회원구.csv into DataFrame '연립다세대(매매)_실거래가_2022년_마산회원구' with shape (154, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_202007_의창구.csv into DataFrame '연립다세대(매매)_실거래가_202007_의창구' with shape (105, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_2021년_마산합포구.csv into DataFrame '연립다세대(매매)_실거래가_2021년_마산합포구' with shape (175, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_202007_마산회원구.csv into DataFrame '연립다세대(매매)_실거래가_202007_마산회원구' with shape (65, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_2022년_의창구.csv into DataFrame '연립다세대(매매)_실거래가_2022년_의창구' with shape (213, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_202007_진해구.csv into DataFrame '연립다세대(매매)_실거래가_202007_진해구' with shape (141, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_2023년_마산합포구.csv into DataFrame '연립다세대(매매)_실거래가_2023년_마산합포구' with shape (91, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_202007_성산구.csv into DataFrame '연립다세대(매매)_실거래가_202007_성산구' with shape (38, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_2023년_의창구.csv into DataFrame '연립다세대(매매)_실거래가_2023년_의창구' with shape (153, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_2021년_성산구.csv into DataFrame '연립다세대(매매)_실거래가_2021년_성산구' with shape (49, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_2021년_진해구.csv into DataFrame '연립다세대(매매)_실거래가_2021년_진해구' with shape (307, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_2023년_성산구.csv into DataFrame '연립다세대(매매)_실거래가_2023년_성산구' with shape (27, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_2024년_진해구.csv into DataFrame '연립다세대(매매)_실거래가_2024년_진해구' with shape (156, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_2021년_의창구.csv into DataFrame '연립다세대(매매)_실거래가_2021년_의창구' with shape (156, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_2022년_마산합포구.csv into DataFrame '연립다세대(매매)_실거래가_2022년_마산합포구' with shape (132, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_2024년_의창구.csv into DataFrame '연립다세대(매매)_실거래가_2024년_의창구' with shape (104, 21)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 202007~2024년/연립다세대(매매)_실거래가_2021년_마산회원구.csv into DataFrame '연립다세대(매매)_실거래가_2021년_마산회원구' with shape (229, 21)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_2021년_마산합포구.csv into DataFrame '오피스텔(매매)_실거래가_2021년_마산합포구' with shape (166, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_2022년_의창구.csv into DataFrame '오피스텔(매매)_실거래가_2022년_의창구' with shape (119, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_2024년_마산회원구.csv into DataFrame '오피스텔(매매)_실거래가_2024년_마산회원구' with shape (99, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_2021년_진해구.csv into DataFrame '오피스텔(매매)_실거래가_2021년_진해구' with shape (72, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_202007_진해구.csv into DataFrame '오피스텔(매매)_실거래가_202007_진해구' with shape (35, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_20222년_마산합포구.csv into DataFrame '오피스텔(매매)_실거래가_20222년_마산합포구' with shape (195, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_2021년_성산구.csv into DataFrame '오피스텔(매매)_실거래가_2021년_성산구' with shape (508, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_202007_의창구.csv into DataFrame '오피스텔(매매)_실거래가_202007_의창구' with shape (41, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_2024년_마산합포구.csv into DataFrame '오피스텔(매매)_실거래가_2024년_마산합포구' with shape (229, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_202007_성산구.csv into DataFrame '오피스텔(매매)_실거래가_202007_성산구' with shape (312, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_2024년_성산구.csv into DataFrame '오피스텔(매매)_실거래가_2024년_성산구' with shape (584, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_2023년_마산회원구.csv into DataFrame '오피스텔(매매)_실거래가_2023년_마산회원구' with shape (42, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_2024년_의창구.csv into DataFrame '오피스텔(매매)_실거래가_2024년_의창구' with shape (90, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_2023년_성산구.csv into DataFrame '오피스텔(매매)_실거래가_2023년_성산구' with shape (351, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_2022년_진해구.csv into DataFrame '오피스텔(매매)_실거래가_2022년_진해구' with shape (74, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_202007_마산회원구.csv into DataFrame '오피스텔(매매)_실거래가_202007_마산회원구' with shape (27, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_2023년_의창구.csv into DataFrame '오피스텔(매매)_실거래가_2023년_의창구' with shape (71, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_2022년_성산구.csv into DataFrame '오피스텔(매매)_실거래가_2022년_성산구' with shape (377, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_202007_마산합포구.csv into DataFrame '오피스텔(매매)_실거래가_202007_마산합포구' with shape (162, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_2022년_마산회원구.csv into DataFrame '오피스텔(매매)_실거래가_2022년_마산회원구' with shape (63, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_2023년_마산합포구.csv into DataFrame '오피스텔(매매)_실거래가_2023년_마산합포구' with shape (239, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_2024년_진해구.csv into DataFrame '오피스텔(매매)_실거래가_2024년_진해구' with shape (273, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_2023년_진해구.csv into DataFrame '오피스텔(매매)_실거래가_2023년_진해구' with shape (49, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_2021년_마산회원구.csv into DataFrame '오피스텔(매매)_실거래가_2021년_마산회원구' with shape (76, 18)
# Loaded csv_preprocessing/창원시 오피스텔(매매)_실거래가 202007~2024년/오피스텔(매매)_실거래가_2021년_의창구.csv into DataFrame '오피스텔(매매)_실거래가_2021년_의창구' with shape (92, 18)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/4. 마산회원구_단독다가구(매매)_실거래가_1501-1506.csv into DataFrame '4__마산회원구_단독다가구(매매)_실거래가_1501_1506' with shape (483, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/2. 성산구_단독다가구(매매)_실거래가_1707-1806.csv into DataFrame '2__성산구_단독다가구(매매)_실거래가_1707_1806' with shape (74, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/3. 마산합포구_단독다가구(매매)_실거래가_1907-2006.csv into DataFrame '3__마산합포구_단독다가구(매매)_실거래가_1907_2006' with shape (248, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/4. 마산회원구_단독다가구(매매)_실거래가_1807-1906.csv into DataFrame '4__마산회원구_단독다가구(매매)_실거래가_1807_1906' with shape (209, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/3. 마산합포구_단독다가구(매매)_실거래가_1707-1806.csv into DataFrame '3__마산합포구_단독다가구(매매)_실거래가_1707_1806' with shape (409, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/3. 마산합포구_단독다가구(매매)_실거래가_1501-1506.csv into DataFrame '3__마산합포구_단독다가구(매매)_실거래가_1501_1506' with shape (380, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/5. 진해구_단독다가구(매매)_실거래가_1707-1806.csv into DataFrame '5__진해구_단독다가구(매매)_실거래가_1707_1806' with shape (347, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/5. 진해구_단독다가구(매매)_실거래가_1501-1506.csv into DataFrame '5__진해구_단독다가구(매매)_실거래가_1501_1506' with shape (406, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/2. 성산구_단독다가구(매매)_실거래가_1501-1506.csv into DataFrame '2__성산구_단독다가구(매매)_실거래가_1501_1506' with shape (155, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/1. 의창구_단독다가구(매매)_실거래가_1807-1906.csv into DataFrame '1__의창구_단독다가구(매매)_실거래가_1807_1906' with shape (280, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/4. 마산회원구_단독다가구(매매)_실거래가_1707-1806.csv into DataFrame '4__마산회원구_단독다가구(매매)_실거래가_1707_1806' with shape (440, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/2. 성산구_단독다가구(매매)_실거래가_1507-1606.csv into DataFrame '2__성산구_단독다가구(매매)_실거래가_1507_1606' with shape (193, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/3. 마산합포구_단독다가구(매매)_실거래가_1807-1906.csv into DataFrame '3__마산합포구_단독다가구(매매)_실거래가_1807_1906' with shape (248, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/4. 마산회원구_단독다가구(매매)_실거래가_1607-1706.csv into DataFrame '4__마산회원구_단독다가구(매매)_실거래가_1607_1706' with shape (659, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/2. 성산구_단독다가구(매매)_실거래가_1907-2006.csv into DataFrame '2__성산구_단독다가구(매매)_실거래가_1907_2006' with shape (93, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/5. 진해구_단독다가구(매매)_실거래가_1907-2006.csv into DataFrame '5__진해구_단독다가구(매매)_실거래가_1907_2006' with shape (248, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/3. 마산합포구_단독다가구(매매)_실거래가_1607-1706.csv into DataFrame '3__마산합포구_단독다가구(매매)_실거래가_1607_1706' with shape (565, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/1. 의창구_단독다가구(매매)_실거래가_1501-1506.csv into DataFrame '1__의창구_단독다가구(매매)_실거래가_1501_1506' with shape (540, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/1. 의창구_단독다가구(매매)_실거래가_1707-1806.csv into DataFrame '1__의창구_단독다가구(매매)_실거래가_1707_1806' with shape (346, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/4. 마산회원구_단독다가구(매매)_실거래가_1507-1606.csv into DataFrame '4__마산회원구_단독다가구(매매)_실거래가_1507_1606' with shape (700, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/3. 마산합포구_단독다가구(매매)_실거래가_1507-1606.csv into DataFrame '3__마산합포구_단독다가구(매매)_실거래가_1507_1606' with shape (607, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/1. 의창구_단독다가구(매매)_실거래가_1907-2006.csv into DataFrame '1__의창구_단독다가구(매매)_실거래가_1907_2006' with shape (453, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/4. 마산회원구_단독다가구(매매)_실거래가_1907-2006.csv into DataFrame '4__마산회원구_단독다가구(매매)_실거래가_1907_2006' with shape (426, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/2. 성산구_단독다가구(매매)_실거래가_1607-1706.csv into DataFrame '2__성산구_단독다가구(매매)_실거래가_1607_1706' with shape (134, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/2. 성산구_단독다가구(매매)_실거래가_1807-1906.csv into DataFrame '2__성산구_단독다가구(매매)_실거래가_1807_1906' with shape (66, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/5. 진해구_단독다가구(매매)_실거래가_1607-1706.csv into DataFrame '5__진해구_단독다가구(매매)_실거래가_1607_1706' with shape (444, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/1. 의창구_단독다가구(매매)_실거래가_1607-1706.csv into DataFrame '1__의창구_단독다가구(매매)_실거래가_1607_1706' with shape (529, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/5. 진해구_단독다가구(매매)_실거래가_1507-1606.csv into DataFrame '5__진해구_단독다가구(매매)_실거래가_1507_1606' with shape (602, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/5. 진해구_단독다가구(매매)_실거래가_1807-1906.csv into DataFrame '5__진해구_단독다가구(매매)_실거래가_1807_1906' with shape (192, 11)
# Loaded csv_preprocessing/창원시 단독다가구(매매)_실거래가 201501 ~202006/1. 의창구_단독다가구(매매)_실거래가_1507-1606.csv into DataFrame '1__의창구_단독다가구(매매)_실거래가_1507_1606' with shape (824, 11)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/2. 성산구_연립다세대(매매)_실거래가_1607-1706.csv into DataFrame '2__성산구_연립다세대(매매)_실거래가_1607_1706' with shape (23, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/1. 의창구_연립다세대(매매)_실거래가_1807_1906.csv into DataFrame '1__의창구_연립다세대(매매)_실거래가_1807_1906' with shape (105, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/2. 성산구_연립다세대(매매)_실거래가_1501-1506.csv into DataFrame '2__성산구_연립다세대(매매)_실거래가_1501_1506' with shape (14, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/2. 성산구_연립다세대(매매)_실거래가_1907-2006.csv into DataFrame '2__성산구_연립다세대(매매)_실거래가_1907_2006' with shape (41, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/4. 마산회원구_연립다세대(매매)_실거래가_1707-1806.csv into DataFrame '4__마산회원구_연립다세대(매매)_실거래가_1707_1806' with shape (222, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/2. 성산구_연립다세대(매매)_실거래가_1807-1906.csv into DataFrame '2__성산구_연립다세대(매매)_실거래가_1807_1906' with shape (17, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/1. 의창구_연립다세대(매매)_실거래가_1707_1806.csv into DataFrame '1__의창구_연립다세대(매매)_실거래가_1707_1806' with shape (138, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/1. 의창구_연립다세대(매매)_실거래가_1907_2006.csv into DataFrame '1__의창구_연립다세대(매매)_실거래가_1907_2006' with shape (113, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/2. 성산구_연립다세대(매매)_실거래가_1507-1606.csv into DataFrame '2__성산구_연립다세대(매매)_실거래가_1507_1606' with shape (28, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/5. 진해구_연립다세대(매매)_실거래가_1507-1606.csv into DataFrame '5__진해구_연립다세대(매매)_실거래가_1507_1606' with shape (260, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/3. 마산합포구_연립다세대(매매)_실거래가_1607-1706.csv into DataFrame '3__마산합포구_연립다세대(매매)_실거래가_1607_1706' with shape (127, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/5. 진해구_연립다세대(매매)_실거래가_1907-2006.csv into DataFrame '5__진해구_연립다세대(매매)_실거래가_1907_2006' with shape (135, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/3. 마산합포구_연립다세대(매매)_실거래가_1501-1506.csv into DataFrame '3__마산합포구_연립다세대(매매)_실거래가_1501_1506' with shape (74, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/5. 진해구_연립다세대(매매)_실거래가_1707-1806.csv into DataFrame '5__진해구_연립다세대(매매)_실거래가_1707_1806' with shape (117, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/3. 마산합포구_연립다세대(매매)_실거래가_1807-1906.csv into DataFrame '3__마산합포구_연립다세대(매매)_실거래가_1807_1906' with shape (46, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/5. 진해구_연립다세대(매매)_실거래가_1501-1506.csv into DataFrame '5__진해구_연립다세대(매매)_실거래가_1501_1506' with shape (192, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/4. 마산회원구_연립다세대(매매)_실거래가_1607-1706.csv into DataFrame '4__마산회원구_연립다세대(매매)_실거래가_1607_1706' with shape (252, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/4. 마산회원구_연립다세대(매매)_실거래가_1807-1906.csv into DataFrame '4__마산회원구_연립다세대(매매)_실거래가_1807_1906' with shape (157, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/5. 진해구_연립다세대(매매)_실거래가_1807-1906.csv into DataFrame '5__진해구_연립다세대(매매)_실거래가_1807_1906' with shape (104, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/4. 마산회원구_연립다세대(매매)_실거래가_1501-1506.csv into DataFrame '4__마산회원구_연립다세대(매매)_실거래가_1501_1506' with shape (199, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/2. 성산구_연립다세대(매매)_실거래가_1707-1806.csv into DataFrame '2__성산구_연립다세대(매매)_실거래가_1707_1806' with shape (20, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/3. 마산합포구_연립다세대(매매)_실거래가_1707-1806.csv into DataFrame '3__마산합포구_연립다세대(매매)_실거래가_1707_1806' with shape (73, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/3. 마산합포구_연립다세대(매매)_실거래가_1907-2006.csv into DataFrame '3__마산합포구_연립다세대(매매)_실거래가_1907_2006' with shape (59, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/4. 마산회원구_연립다세대(매매)_실거래가_1907-2006.csv into DataFrame '4__마산회원구_연립다세대(매매)_실거래가_1907_2006' with shape (172, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/3. 마산합포구_연립다세대(매매)_실거래가_1507-1606.csv into DataFrame '3__마산합포구_연립다세대(매매)_실거래가_1507_1606' with shape (117, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/1. 의창구_연립다세대(매매)_실거래가_1607_1706.csv into DataFrame '1__의창구_연립다세대(매매)_실거래가_1607_1706' with shape (228, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/5. 진해구_연립다세대(매매)_실거래가_1607-1706.csv into DataFrame '5__진해구_연립다세대(매매)_실거래가_1607_1706' with shape (228, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/1. 의창구_연립다세대(매매)_실거래가_1507-1606.csv into DataFrame '1__의창구_연립다세대(매매)_실거래가_1507_1606' with shape (298, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/4. 마산회원구_연립다세대(매매)_실거래가_1507-1606.csv into DataFrame '4__마산회원구_연립다세대(매매)_실거래가_1507_1606' with shape (304, 13)
# Loaded csv_preprocessing/창원시 연립다세대(매매)_실거래가 201501~202006/1. 의창구_연립다세대(매매)_실거래가_1501-1506.csv into DataFrame '1__의창구_연립다세대(매매)_실거래가_1501_1506' with shape (208, 13)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_20200701_마산합포구.csv into DataFrame '아파트(매매)_실거래가_20200701_마산합포구' with shape (1342, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_2023년_의창구.csv into DataFrame '아파트(매매)_실거래가_2023년_의창구' with shape (1551, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_2022년_성산구.csv into DataFrame '아파트(매매)_실거래가_2022년_성산구' with shape (2695, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_2024년_마산회원구.csv into DataFrame '아파트(매매)_실거래가_2024년_마산회원구' with shape (1680, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_2021년_마산합포구.csv into DataFrame '아파트(매매)_실거래가_2021년_마산합포구' with shape (3327, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_2022년_진해구.csv into DataFrame '아파트(매매)_실거래가_2022년_진해구' with shape (2240, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_2023년_진해구.csv into DataFrame '아파트(매매)_실거래가_2023년_진해구' with shape (1686, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_2022년_의창구.csv into DataFrame '아파트(매매)_실거래가_2022년_의창구' with shape (1239, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_2022년_마산회원구.csv into DataFrame '아파트(매매)_실거래가_2022년_마산회원구' with shape (1726, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_2024년_성산구.csv into DataFrame '아파트(매매)_실거래가_2024년_성산구' with shape (3065, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_2022년_마산합포구.csv into DataFrame '아파트(매매)_실거래가_2022년_마산합포구' with shape (1644, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_2023년_성산구.csv into DataFrame '아파트(매매)_실거래가_2023년_성산구' with shape (3448, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_2024년_마산합포구.csv into DataFrame '아파트(매매)_실거래가_2024년_마산합포구' with shape (1859, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_2024년_의창구.csv into DataFrame '아파트(매매)_실거래가_2024년_의창구' with shape (1690, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_2021년_진해구.csv into DataFrame '아파트(매매)_실거래가_2021년_진해구' with shape (3187, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_2021년_마산회원구.csv into DataFrame '아파트(매매)_실거래가_2021년_마산회원구' with shape (2987, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_2024년_진해구.csv into DataFrame '아파트(매매)_실거래가_2024년_진해구' with shape (1775, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_2023년_마산합포구.csv into DataFrame '아파트(매매)_실거래가_2023년_마산합포구' with shape (1673, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_20200701_성산구.csv into DataFrame '아파트(매매)_실거래가_20200701_성산구' with shape (4906, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_2023년_마산회원구.csv into DataFrame '아파트(매매)_실거래가_2023년_마산회원구' with shape (1621, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_20200701_진해구.csv into DataFrame '아파트(매매)_실거래가_20200701_진해구' with shape (2307, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_2000701_마산회원구.csv into DataFrame '아파트(매매)_실거래가_2000701_마산회원구' with shape (1770, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_2021년_의창구.csv into DataFrame '아파트(매매)_실거래가_2021년_의창구' with shape (2026, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_2021년_성산구.csv into DataFrame '아파트(매매)_실거래가_2021년_성산구' with shape (5088, 21)
# Loaded csv_preprocessing/창원시 아파트(매매)_실거래가 202007~2024년/아파트(매매)_실거래가_20200701_의창구.csv into DataFrame '아파트(매매)_실거래가_20200701_의창구' with shape (1542, 21)

# %%
# 데이터프레임 이름 정제작업.
"""
데이터프레임 이름은 다음과 같은 경향성이 관찰됨.
    - "1. 의창구_단독다가구(매매)_실거래가_1501-1506.csv"
    - "2__성산구_연립다세대(매매)_실거래가_1507_1606.csv"
    - "3__마산합포구_아파트(매매)_실거래가_1907_2006.csv"
    - "단독다가구(매매)_실거래가_2021년_마산회원구"
    - "단독다가구(매매)_실거래가_202007_마산합포구"
따라서, 데이터프레임에서 다음과 같은 키워드를 캐치하여 데이터프레임을 정제할 필요가 있음.
    - 지역구: 의창구, 성산구, 마산합포구, 마산회원구, 진해구
    - 주택유형: 단독다가구, 연립다세대, 아파트, 오피스텔
    - 거래유형: 매매, 전월세
    - 기간: 1501-1506, 1507_1606, 2021년 등등
"""

# 우선, 같은 지역구 끼리 묶어서 개별 리스트에 보관.
uichang_gu_dfs = []
seongsan_gu_dfs = []
masanhappo_gu_dfs = []
masanhoeweon_gu_dfs = []
jinhe_gu_dfs = []

# 데이터프레임 이름을 순회하며 지역구 키워드에 따라 분류.
for df_name in list(globals().keys()):
    if "의창구" in df_name:
        uichang_gu_dfs.append(df_name)
    elif "성산구" in df_name:
        seongsan_gu_dfs.append(df_name)
    elif "마산합포구" in df_name:
        masanhappo_gu_dfs.append(df_name)
    elif "마산회원구" in df_name:
        masanhoeweon_gu_dfs.append(df_name)
    elif "진해구" in df_name:
        jinhe_gu_dfs.append(df_name)

# 주택유형에 따라 지역구_주택유형_df 형태로 분류.
uichang_gu_dfs_dict = {"단독다가구": [], "연립다세대": [], "아파트": [], "오피스텔": []}
seongsan_gu_dfs_dict = {"단독다가구": [], "연립다세대": [], "아파트": [], "오피스텔": []}
masanhappo_gu_dfs_dict = {"단독다가구": [], "연립다세대": [], "아파트": [], "오피스텔": []}
masanhoeweon_gu_dfs_dict = {"단독다가구": [], "연립다세대": [], "아파트": [], "오피스텔": []}
jinhe_gu_dfs_dict = {"단독다가구": [], "연립다세대": [], "아파트": [], "오피스텔": []}

for df_name in uichang_gu_dfs:
    if "단독다가구" in df_name:
        uichang_gu_dfs_dict["단독다가구"].append(df_name)
    elif "연립다세대" in df_name:
        uichang_gu_dfs_dict["연립다세대"].append(df_name)
    elif "아파트" in df_name:
        uichang_gu_dfs_dict["아파트"].append(df_name)
    elif "오피스텔" in df_name:
        uichang_gu_dfs_dict["오피스텔"].append(df_name)

for df_name in seongsan_gu_dfs:
    if "단독다가구" in df_name:
        seongsan_gu_dfs_dict["단독다가구"].append(df_name)
    elif "연립다세대" in df_name:
        seongsan_gu_dfs_dict["연립다세대"].append(df_name)
    elif "아파트" in df_name:
        seongsan_gu_dfs_dict["아파트"].append(df_name)
    elif "오피스텔" in df_name:
        seongsan_gu_dfs_dict["오피스텔"].append(df_name)

for df_name in masanhappo_gu_dfs:
    if "단독다가구" in df_name:
        masanhappo_gu_dfs_dict["단독다가구"].append(df_name)
    elif "연립다세대" in df_name:
        masanhappo_gu_dfs_dict["연립다세대"].append(df_name)
    elif "아파트" in df_name:
        masanhappo_gu_dfs_dict["아파트"].append(df_name)
    elif "오피스텔" in df_name:
        masanhappo_gu_dfs_dict["오피스텔"].append(df_name)

for df_name in masanhoeweon_gu_dfs:
    if "단독다가구" in df_name:
        masanhoeweon_gu_dfs_dict["단독다가구"].append(df_name)
    elif "연립다세대" in df_name:
        masanhoeweon_gu_dfs_dict["연립다세대"].append(df_name)
    elif "아파트" in df_name:
        masanhoeweon_gu_dfs_dict["아파트"].append(df_name)
    elif "오피스텔" in df_name:
        masanhoeweon_gu_dfs_dict["오피스텔"].append(df_name)

for df_name in jinhe_gu_dfs:
    if "단독다가구" in df_name:
        jinhe_gu_dfs_dict["단독다가구"].append(df_name)
    elif "연립다세대" in df_name:
        jinhe_gu_dfs_dict["연립다세대"].append(df_name)
    elif "아파트" in df_name:
        jinhe_gu_dfs_dict["아파트"].append(df_name)
    elif "오피스텔" in df_name:
        jinhe_gu_dfs_dict["오피스텔"].append(df_name)

# %%
# 지역구 사전의 키를 순회하며, 주택유형별로 데이터프레임을 병합.
for gu_dict, gu_name in zip(
    [uichang_gu_dfs_dict, seongsan_gu_dfs_dict, masanhappo_gu_dfs_dict, masanhoeweon_gu_dfs_dict, jinhe_gu_dfs_dict],
    ["의창구", "성산구", "마산합포구", "마산회원구", "진해구"]
):
    for housing_type, df_names in gu_dict.items():
        if df_names:  # df_names 리스트가 비어있지 않은 경우에만 병합 수행
            merged_df = pd.concat([globals()[df_name] for df_name in df_names], ignore_index=True)
            merged_df_name = f"{gu_name}_{housing_type}_merged"

            # '계약년월' 컬럼 기준으로 오름차순 정렬
            if '계약년월' in merged_df.columns:
                merged_df = merged_df.sort_values(by='계약년월').reset_index(drop=True)

            globals()[merged_df_name] = merged_df
            print(f"Merged {len(df_names)} DataFrames into '{merged_df_name}' with shape {merged_df.shape}")

# 병합된 데이터프레임을 csv로 저장.
output_folder = './csv_merged'
os.makedirs(output_folder, exist_ok=True)
for var_name in list(globals().keys()):
    if var_name.endswith("_merged"):
        df = globals()[var_name]
        df.to_csv(f"{output_folder}/{var_name}.csv", index=False)
        print(f"Saved merged DataFrame to '{output_folder}/{var_name}.csv'")
# Out:
# Merged 11 DataFrames into '의창구_단독다가구_merged' with shape (4238, 17)
# Merged 11 DataFrames into '의창구_연립다세대_merged' with shape (1821, 21)
# Merged 11 DataFrames into '의창구_아파트_merged' with shape (17625, 21)
# Merged 11 DataFrames into '의창구_오피스텔_merged' with shape (901, 18)
# Merged 11 DataFrames into '성산구_단독다가구_merged' with shape (1368, 17)
# Merged 11 DataFrames into '성산구_연립다세대_merged' with shape (299, 21)
# Merged 11 DataFrames into '성산구_아파트_merged' with shape (39202, 21)
# Merged 11 DataFrames into '성산구_오피스텔_merged' with shape (3298, 18)
# Merged 11 DataFrames into '마산합포구_단독다가구_merged' with shape (4696, 17)
# Merged 11 DataFrames into '마산합포구_연립다세대_merged' with shape (971, 21)
# Merged 11 DataFrames into '마산합포구_아파트_merged' with shape (17754, 21)
# Merged 11 DataFrames into '마산합포구_오피스텔_merged' with shape (2126, 18)
# Merged 11 DataFrames into '마산회원구_단독다가구_merged' with shape (4078, 17)
# Merged 11 DataFrames into '마산회원구_연립다세대_merged' with shape (2046, 21)
# Merged 11 DataFrames into '마산회원구_아파트_merged' with shape (19736, 21)
# Merged 11 DataFrames into '마산회원구_오피스텔_merged' with shape (683, 18)
# Merged 11 DataFrames into '진해구_단독다가구_merged' with shape (3526, 17)
# Merged 11 DataFrames into '진해구_연립다세대_merged' with shape (2041, 21)
# Merged 11 DataFrames into '진해구_아파트_merged' with shape (21503, 21)
# Merged 11 DataFrames into '진해구_오피스텔_merged' with shape (770, 18)
# Saved merged DataFrame '의창구_단독다가구_merged' to './csv_merged/의창구_단독다가구_merged.csv'
# Saved merged DataFrame '의창구_연립다세대_merged' to './csv_merged/의창구_연립다세대_merged.csv'
# Saved merged DataFrame '의창구_아파트_merged' to './csv_merged/의창구_아파트_merged.csv'
# Saved merged DataFrame '의창구_오피스텔_merged' to './csv_merged/의창구_오피스텔_merged.csv'
# Saved merged DataFrame '성산구_단독다가구_merged' to './csv_merged/성산구_단독다가구_merged.csv'
# Saved merged DataFrame '성산구_연립다세대_merged' to './csv_merged/성산구_연립다세대_merged.csv'
# Saved merged DataFrame '성산구_아파트_merged' to './csv_merged/성산구_아파트_merged.csv'
# Saved merged DataFrame '성산구_오피스텔_merged' to './csv_merged/성산구_오피스텔_merged.csv'
# Saved merged DataFrame '마산합포구_단독다가구_merged' to './csv_merged/마산합포구_단독다가구_merged.csv'
# Saved merged DataFrame '마산합포구_연립다세대_merged' to './csv_merged/마산합포구_연립다세대_merged.csv'
# Saved merged DataFrame '마산합포구_아파트_merged' to './csv_merged/마산합포구_아파트_merged.csv'
# Saved merged DataFrame '마산합포구_오피스텔_merged' to './csv_merged/마산합포구_오피스텔_merged.csv'
# Saved merged DataFrame '마산회원구_단독다가구_merged' to './csv_merged/마산회원구_단독다가구_merged.csv'
# Saved merged DataFrame '마산회원구_연립다세대_merged' to './csv_merged/마산회원구_연립다세대_merged.csv'
# Saved merged DataFrame '마산회원구_아파트_merged' to './csv_merged/마산회원구_아파트_merged.csv'
# Saved merged DataFrame '마산회원구_오피스텔_merged' to './csv_merged/마산회원구_오피스텔_merged.csv'
# Saved merged DataFrame '진해구_단독다가구_merged' to './csv_merged/진해구_단독다가구_merged.csv'
# Saved merged DataFrame '진해구_연립다세대_merged' to './csv_merged/진해구_연립다세대_merged.csv'
# Saved merged DataFrame '진해구_아파트_merged' to './csv_merged/진해구_아파트_merged.csv'
# Saved merged DataFrame '진해구_오피스텔_merged' to './csv_merged/진해구_오피스텔_merged.csv'

# %% [markdown]
# #

# %% [markdown]
# ## 필요에 따라 도로명 주소를 좌표로 변환하기 위한 코드블럭.

# %%
# 모든 Merged DataFrame들을 순회하며 '도로명'컬럼의 고유값을 추출
unique_road_names = set()
for var_name in list(globals().keys()):
    if var_name.endswith("_merged"):
        df = globals()[var_name]
        df['도로명'] = df['도로명'].str.strip()
        unique_road_names.update(df['도로명'].dropna().unique())

unique_road_names = sorted(unique_road_names)
print(f"Extracted {len(unique_road_names)} unique road names.")
# Out:
# Extracted 5223 unique road names.

# %%
# csv로 저장
road_names_df = pd.DataFrame(unique_road_names, columns=['도로명'])
road_names_df.to_csv('./csv_merged/unique_road_names.csv', index=False)
